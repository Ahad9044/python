# %%
if (True):
    print("This is true")
    if(False):
        print("This is also true")
    print("This is still true")
# Out:
# This is true
# This is still true

# %%
age= "25"
print(type(int(age)))
# Out:
# <class 'int'>

# %%
a= int(input("Enter a number"))
print(a+10)
if a>10 : print("true")
else: print("false")
# Out:
# 11
# false

# %%
a=[1,4,2,3,5,6]
for i in a:
    print(i)
# Out:
# 1
# 4
# 2
# 3
# 5
# 6

# %%
for num in range(1,101):
    if num>1 : 
        for i in range(2,num) :
            if num % i == 0 : 
             break
        else:
               print(num)

# %%
numbers= [1,2,3,4,5,6,7]
print(numbers[2:4])
print(numbers[2:])
print(numbers[:4])
print(numbers[::-1])
# Out:
# [3, 4]
# [3, 4, 5, 6, 7]
# [1, 2, 3, 4]
# [7, 6, 5, 4, 3, 2, 1]

# %%
l1= [1,2,3,4,5,6,7]
l2=["a","s","d","f","g","h"]
l3= ([i,j] for i in l1 for j in l2)
print(l3)
# Out:
# <generator object <genexpr> at 0x000001EBDED4C9E0>

# %%
sq= [num**2 for num in range(10) if num%2==0]
print(sq)
# Out:
# [0, 4, 16, 36, 64]

# %%
words= ["apple" , "banana" , "grape", "lemon"]
char =[len(word) for word in words ]
print(char)
# Out:
# [5, 6, 5, 5]

# %%
l1= [1,2,3,4,5,6,7]
l2=["a","s","d","f","g","h"]
l4=[2,3,4,7,9,0,1]
l3= [[i,j] for i in l1 for j in l2]
print(l3)
# Out:
# [[1, 'a'], [1, 's'], [1, 'd'], [1, 'f'], [1, 'g'], [1, 'h'], [2, 'a'], [2, 's'], [2, 'd'], [2, 'f'], [2, 'g'], [2, 'h'], [3, 'a'], [3, 's'], [3, 'd'], [3, 'f'], [3, 'g'], [3, 'h'], [4, 'a'], [4, 's'], [4, 'd'], [4, 'f'], [4, 'g'], [4, 'h'], [5, 'a'], [5, 's'], [5, 'd'], [5, 'f'], [5, 'g'], [5, 'h'], [6, 'a'], [6, 's'], [6, 'd'], [6, 'f'], [6, 'g'], [6, 'h'], [7, 'a'], [7, 's'], [7, 'd'], [7, 'f'], [7, 'g'], [7, 'h']]

# %%
# concatinatio
tup1=(1,3,5, "hello" , "world")
tup2=("w", 2,5)
print(tup1 + tup2)
# Out:
# (1, 3, 5, 'hello', 'world', 'w', 2, 5)

# %%
# Operation 

print(tup1*3)
# Out:
# (1, 3, 5, 'hello', 'world', 1, 3, 5, 'hello', 'world', 1, 3, 5, 'hello', 'world')

# %%
num= (1,2,3,4,4,6)
print(num.count(4))
print(num.index(4))
# Out:
# 2
# 3

# %%
#packing and unpacking tuple

packed_tuple = 1 , "hello" , "world"
print(packed_tuple)
# Out:
# (1, 'hello', 'world')

# %%
a , b , c = packed_tuple
print(a)
print(b)
print(c)
# Out:
# 1
# hello
# world

# %%
a=(1,2,3,4,5,6,7,89,0)
first, *second , third = a

print(first)
print(second)
print(third)
# Out:
# 1
# [2, 3, 4, 5, 6, 7, 89]
# 0
